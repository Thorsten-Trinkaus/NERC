# %% [markdown]
# ---
# # NLI Analysis - OntoNotes
# > Laura Komorek
# ---

# %% [markdown]
# This notebook analyzes the performance of the fine-tuned RoBERTa-Base model on the OntoNotes test set.
#
# We are focusing on:
# - Error Analysis
# - Robustness and Probing

# %% [markdown]
# ---
# ## Imports

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np
import random
import torch
import spacy
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import confusion_matrix

# %matplotlib inline

# %% [markdown]
# ---
# ## Load OntoNotes

# %%
with open("ontonotes_test_predictions.json", "r", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)

print(df.columns)
df.head(2)
# Out:
# Index(['premise', 'hypothesis', 'gold_label', 'prediction'], dtype='object')
#                                              premise       hypothesis  \
# 0  SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...  JAPAN is a per.
# 1  SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...  JAPAN is a loc.
#
#        gold_label      prediction
# 0  NOT ENTAILMENT  NOT ENTAILMENT
# 1      ENTAILMENT  NOT ENTAILMENT

# %% [markdown]
# ---
# ## Label Distribution and Baselines

# %%
sns.countplot(x='gold_label', data=df)
plt.title('Gold Label Distribution – OntoNotes')
plt.show()

sns.countplot(x='prediction', data=df)
plt.title('Prediction Distribution – OntoNotes')
plt.show()

# %% [markdown]
# ---
# ## Confusion Matrix

# %%
label_order = ["ENTAILMENT", "NOT ENTAILMENT"]

cm = confusion_matrix(df['gold_label'], df['prediction'], labels=label_order)
cm_df = pd.DataFrame(cm, index=label_order, columns=label_order)

plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Gold Label')
plt.xlabel('Prediction')
plt.title('Confusion Matrix – OntoNotes')
plt.show()

# %% [markdown]
# ---
# ## Misclassification and Ambiguity Cases

# %%
fp = df[(df['gold_label']=='NOT ENTAILMENT') & (df['prediction']=='ENTAILMENT')]
print(f"Number of FP: {len(fp)}")
fp.head(5)

fn = df[(df['gold_label']=='ENTAILMENT') & (df['prediction']=='NOT ENTAILMENT')]
print(f"Number of FN: {len(fn)}")
fn.head(5)
# Out:
# Number of FP: 0
# Number of FN: 5648
#                                               premise  \
# 1   SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...
# 4   SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...
# 8                                         Nadim Ladki
# 13           AL-AIN , United Arab Emirates 1996-12-06
# 17           AL-AIN , United Arab Emirates 1996-12-06
#
#                         hypothesis  gold_label      prediction
# 1                  JAPAN is a loc.  ENTAILMENT  NOT ENTAILMENT
# 4                  CHINA is a per.  ENTAILMENT  NOT ENTAILMENT
# 8            Nadim Ladki is a per.  ENTAILMENT  NOT ENTAILMENT
# 13                AL-AIN is a loc.  ENTAILMENT  NOT ENTAILMENT
# 17  United Arab Emirates is a loc.  ENTAILMENT  NOT ENTAILMENT

# %% [markdown]
# ---
# ## Robustness Test
#
# We perform two complementary masking tests, such as:
#
# 1. Entity-Type-Masking: mask only certain entity types in hypothesis
# 2. Span/Clause Masking: mask full noun or verb phrases to test phrase-level roboustness

# %%
nlp = spacy.load("en_core_web_sm", disable=["tagger", "lemmatizer"])

def mask_entities(text, entity_type="PERSON"):
    doc = nlp(text)
    masked_tokens = []
    for token in doc:
        if any(ent.label_ == entity_type for ent in doc.ents if token.idx >= ent.start_char and token.idx < ent.end_char):
            masked_tokens.append('[MASK]')
        else:
            masked_tokens.append(token.text)
    return ' '.join(masked_tokens)

def mask_phrases(text):
    doc = nlp(text)
    masked_tokens = []
    for chunk in doc.noun_chunks:
        for token in chunk:
            masked_tokens.append('[MASK]')
    masked_set = set(token.text for chunk in doc.noun_chunks for token in chunk)
    for token in doc:
        if token.text not in masked_set:
            masked_tokens.append(token.text)
    return ' '.join(masked_tokens)

df['hyp_mask_person'] = [mask_entities(hyp, "PERSON") for hyp in tqdm(df['hypothesis'], desc="Mask Person")]
df['hyp_mask_span']   = [mask_phrases(hyp) for hyp in tqdm(df['hypothesis'], desc="Mask Span")]

df.to_csv("ontonotes_masked.csv", index=False)
# Out:
# Mask Person: 100%|██████████| 22592/22592 [01:46<00:00, 212.62it/s]
# Mask Span: 100%|██████████| 22592/22592 [01:40<00:00, 225.79it/s]

# %% [markdown]
# ---
# ## Load fine-tuned Model

# %%
model_path = r"C:\Users\Laura\Desktop\Uni\5. Semester (WS25-26)\Formale Semantik\Projekt\Analysis\OntoNotes Experiments\ontonotes_predictions__none__premise_sep_hypothesis"

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=False)

print("Loading model...")
model = AutoModelForSequenceClassification.from_pretrained(model_path)

print("Setting eval mode...")
model.eval()

print("Done!")
# Out:
# Loading tokenizer...
# Loading model...
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Setting eval mode...
# Done!

# %% [markdown]
# ---
# ## Run Masked Inputs on fine-tuned Model

# %%
def predict_batch(premises, hypotheses, batch_size=32):
    preds = []
    for i in range(0, len(premises), batch_size):
        batch_p = premises[i:i+batch_size]
        batch_h = hypotheses[i:i+batch_size]
        inputs = tokenizer(batch_p, batch_h, padding=True, truncation=True, return_tensors="pt")
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            batch_preds = torch.argmax(logits, dim=1).tolist()
            preds.extend(batch_preds)
    return preds

# -- Predictions on Masked Inputs
pred_mask_person = predict_batch(df['premise'].tolist(), df['hyp_mask_person'].tolist())
pred_mask_span   = predict_batch(df['premise'].tolist(), df['hyp_mask_span'].tolist())

df['pred_mask_person'] = pred_mask_person
df['pred_mask_span']   = pred_mask_span

# %% [markdown]
# ---
# ## Label Mapping

# %%
label_map = {
    0: "NOT ENTAILMENT",
    1: "ENTAILMENT"
}

df['pred_mask_person_label'] = df['pred_mask_person'].map(label_map)
df['pred_mask_span_label'] = df['pred_mask_span'].map(label_map)

# %% [markdown]
# ---
# ## Robustness Test and Error Analysis on Masked Results

# %%
# -- Robustness Test

df['change_person'] = df['prediction'] != df['pred_mask_person_label']
df['change_span'] = df['prediction'] != df['pred_mask_span_label']

robustness_person = 1 - df['change_person'].mean()
robustness_span = 1 - df['change_span'].mean()

print(f"Robustness (Person Masking): {robustness_person:.2%}")
print(f"Robustness (Span Masking): {robustness_span:.2%}")

# -- Error Analysis

# False Positives (FP)
fp_person = df[
    (df['gold_label'] == 'NOT ENTAILMENT') &
    (df['pred_mask_person_label'] == 'ENTAILMENT')
]

fp_span = df[
    (df['gold_label'] == 'NOT ENTAILMENT') &
    (df['pred_mask_span_label'] == 'ENTAILMENT')
]

# False Negatives (FN)
fn_person = df[
    (df['gold_label'] == 'ENTAILMENT') &
    (df['pred_mask_person_label'] == 'NOT ENTAILMENT')
]

fn_span = df[
    (df['gold_label'] == 'ENTAILMENT') &
    (df['pred_mask_span_label'] == 'NOT ENTAILMENT')
]

print("\nError Analysis")
print("FP Person:", len(fp_person))
print("FN Person:", len(fn_person))
print("FP Span:", len(fp_span))
print("FN Span:", len(fn_span))
# Out:
# Robustness (Person Masking): 100.00%
# Robustness (Span Masking): 100.00%
#
# Error Analysis
# FP Person: 0
# FN Person: 5648
# FP Span: 0
# FN Span: 5648

# %% [markdown]
# ---
# ## Interpretation
#
# The model shows 100% robustness for both the person and span masking. This means that the predictions did not change after masking.
#
# However, the original testset analysis already reveals a strong bias:
# - all "ENTAILMENT" ecamples were miscalssified as "NOT ENTAILMENT" while all "NOT ENTAILMENT" examples were correctly predicted.
#
# Therefore, the 100% robustness does not actually indicate a truly robust model, but rather that the model already fails on positive entailment cases, so masking does not change any predictions.
#
# In summary, the model is highly sensitive to positive entailment and heavily biased towards "NOT ENTAILMENT". Masking does not improve nor worsen its behaviour, because the failure already happens in the unmasked predictions.
